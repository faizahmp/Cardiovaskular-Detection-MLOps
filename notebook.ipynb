# %% [markdown]
# # Import Data & Libraries

# %%
! kaggle datasets download colewelkins/cardiovascular-disease
# Out:
# ^C
# Dataset URL: https://www.kaggle.com/datasets/colewelkins/cardiovascular-disease
# License(s): DbCL-1.0
# cardiovascular-disease.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
with zipfile.ZipFile("cardiovascular-disease.zip", 'r') as zip_ref:
    zip_ref.extractall("data")

print("Files extracted to folder data")
# Out:
# Files extracted to folder data

# %%
import pandas as pd
df = pd.read_csv('data/cardio_data_processed.csv')
df.head(10)
# Out:
#    gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0       2     168    62.0    110     80            1     1      0     0
# 1       1     156    85.0    140     90            3     1      0     0
# 2       1     165    64.0    130     70            3     1      0     0
# 3       2     169    82.0    150    100            1     1      0     0
# 4       1     156    56.0    100     60            1     1      0     0
# 5       1     151    67.0    120     80            2     2      0     0
# 6       1     157    93.0    130     80            3     1      0     0
# 7       2     178    95.0    130     90            3     3      0     0
# 8       1     158    71.0    110     70            1     1      0     0
# 9       1     164    68.0    110     60            1     1      0     0
#
#    active  cardio  age_years        bmi           bp_category  \
# 0       1       0         50  21.967120  Hypertension Stage 1
# 1       1       1         55  34.927679  Hypertension Stage 2
# 2       0       1         51  23.507805  Hypertension Stage 1
# 3       1       1         48  28.710479  Hypertension Stage 2
# 4       0       0         47  23.011177                Normal
# 5       0       0         60  29.384676  Hypertension Stage 1
# 6       1       0         60  37.729725  Hypertension Stage 1
# 7       1       1         61  29.983588  Hypertension Stage 1
# 8       1       0         48  28.440955                Normal
# 9       0       0         54  25.282570                Normal
#
#     bp_category_encoded
# 0  Hypertension Stage 1
# 1  Hypertension Stage 2
# 2  Hypertension Stage 1
# 3  Hypertension Stage 2
# 4                Normal
# 5  Hypertension Stage 1
# 6  Hypertension Stage 1
# 7  Hypertension Stage 1
# 8                Normal
# 9                Normal

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68205 entries, 0 to 68204
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   68205 non-null  int64
#  1   age                  68205 non-null  int64
#  2   gender               68205 non-null  int64
#  3   height               68205 non-null  int64
#  4   weight               68205 non-null  float64
#  5   ap_hi                68205 non-null  int64
#  6   ap_lo                68205 non-null  int64
#  7   cholesterol          68205 non-null  int64
#  8   gluc                 68205 non-null  int64
#  9   smoke                68205 non-null  int64
#  10  alco                 68205 non-null  int64
#  11  active               68205 non-null  int64
#  12  cardio               68205 non-null  int64
#  13  age_years            68205 non-null  int64
#  14  bmi                  68205 non-null  float64
#  15  bp_category          68205 non-null  object
#  16  bp_category_encoded  68205 non-null  object
# dtypes: float64(2), int64(13), object(2)
# memory usage: 8.8+ MB

# %%
df = df.drop(columns=['id','age'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68205 entries, 0 to 68204
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               68205 non-null  int64
#  1   height               68205 non-null  int64
#  2   weight               68205 non-null  float64
#  3   ap_hi                68205 non-null  int64
#  4   ap_lo                68205 non-null  int64
#  5   cholesterol          68205 non-null  int64
#  6   gluc                 68205 non-null  int64
#  7   smoke                68205 non-null  int64
#  8   alco                 68205 non-null  int64
#  9   active               68205 non-null  int64
#  10  cardio               68205 non-null  int64
#  11  age_years            68205 non-null  int64
#  12  bmi                  68205 non-null  float64
#  13  bp_category          68205 non-null  object
#  14  bp_category_encoded  68205 non-null  object
# dtypes: float64(2), int64(11), object(2)
# memory usage: 7.8+ MB

# %%
df.to_csv('data/cardio_data_processed.csv', index=False)

# %%
df.isna().sum()
# Out:
# gender                 0
# height                 0
# weight                 0
# ap_hi                  0
# ap_lo                  0
# cholesterol            0
# gluc                   0
# smoke                  0
# alco                   0
# active                 0
# cardio                 0
# age_years              0
# bmi                    0
# bp_category            0
# bp_category_encoded    0
# dtype: int64

# %%
import os
import zipfile
from typing import Text
import pandas as pd
from absl import logging
from tfx.orchestration import metadata, pipeline
from tfx.orchestration.beam.beam_dag_runner import BeamDagRunner
from modules import components

# %% [markdown]
# # Pipelines

# %% [markdown]
# ## Set Variable Pipelines

# %%
PIPELINE_NAME = "faizahmp-pipeline"
 
# pipeline inputs
DATA_ROOT = "data"
TRANSFORM_MODULE_FILE = "modules/cardiovaskular_transform.py"
TUNER_MODULE_FILE = "modules/cardiovaskular_tuner.py"
TRAINER_MODULE_FILE = "modules/cardiovaskular_trainer.py"
# requirement_file = os.path.join(root, "requirements.txt")
 
# pipeline outputs
OUTPUT_BASE = "outputs"
serving_model_dir = os.path.join(OUTPUT_BASE, 'serving_model')
pipeline_root = os.path.join(OUTPUT_BASE, PIPELINE_NAME)
metadata_path = os.path.join(pipeline_root, "metadata.sqlite")

# %% [markdown]
# ## Initialize local pipeline

# %%
def init_local_pipeline(
    components, pipeline_root: Text
) -> pipeline.Pipeline:
    """
    Initialize a TFX pipeline with components.

    Args:
        components: list of TFX components
        pipeline_root: directory to save pipeline artifacts
    Returns:
        TFX pipeline
    """

    logging.info(f"Pipeline root set to: {pipeline_root}")
    beam_args = [
        "--direct_running_mode=multi_processing",
        # 0 auto-detect based on on the number of CPUs available
        # during execution time.
        "----direct_num_workers=0",
    ]

    return pipeline.Pipeline(
        pipeline_name=PIPELINE_NAME,
        pipeline_root=pipeline_root,
        components=components,
        enable_cache=True,
        metadata_connection_config=metadata.sqlite_metadata_connection_config(
            metadata_path),
        beam_pipeline_args=beam_args
    )

# %%
logging.set_verbosity(logging.INFO)

from modules.components import init_components

p_components = init_components({
    'data_dir': DATA_ROOT,
    'transform_module': TRANSFORM_MODULE_FILE,
    'tuner_module': TUNER_MODULE_FILE,
    'training_module': TRAINER_MODULE_FILE,
    'training_steps': 500,
    'eval_steps': 100,
    'serving_model_dir': serving_model_dir
})

pipeline = init_local_pipeline(p_components, pipeline_root)
BeamDagRunner().run(pipeline=pipeline)
# Out:
# Trial 20 Complete [00h 00m 08s]
# val_binary_accuracy: 0.6850000023841858
#
# Best val_binary_accuracy So Far: 0.7357812523841858
# Total elapsed time: 00h 02m 39s
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:absl:Finished tuning... Tuner ID: tuner0
# INFO:absl:Best HyperParameters: {'space': [{'class_name': 'Choice', 'config': {'name': 'num_layers', 'default': 1, 'conditions': [], 'values': [1, 2, 3], 'ordered': True}}, {'class_name': 'Int', 'config': {'name': 'dense_units', 'default': None, 'conditions': [], 'min_value': 16, 'max_value': 256, 'step': 16, 'sampling': 'linear'}}, {'class_name': 'Float', 'config': {'name': 'dropout_rate', 'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.7, 'step': 0.1, 'sampling': 'linear'}}, {'class_name': 'Choice', 'config': {'name': 'learning_rate', 'default': 0.001, 'conditions': [], 'values': [0.001, 0.0001, 1e-05], 'ordered': True}}], 'values': {'num_layers': 2, 'dense_units': 80, 'dropout_rate': 0.1, 'learning_rate': 0.001}}
# INFO:absl:Best Hyperparameters are written to outputs\faizahmp-pipeline\Tuner\best_hyperparameters\69\best_hyperparameters.txt.
# Results summary
# Results in outputs\faizahmp-pipeline\Tuner\.system\executor_execution\69\.temp\69\cardiovaskular_kt
# Showing 10 best trials
# Objective(name="val_binary_accuracy", direction="max")
#
# Trial 15 summary
# Hyperparameters:
# num_layers: 2
# dense_units: 80
# dropout_rate: 0.1
# learning_rate: 0.001
# Score: 0.7357812523841858
#
# Trial 11 summary
# Hyperparameters:
# num_layers: 2
# dense_units: 144
# dropout_rate: 0.2
# learning_rate: 0.001
# Score: 0.7298437356948853
#
# Trial 13 summary
# Hyperparameters:
# num_layers: 2
# dense_units: 96
# dropout_rate: 0.6
# learning_rate: 0.001
# Score: 0.7281249761581421
#
# Trial 02 summary
# Hyperparameters:
# num_layers: 3
# dense_units: 64
# dropout_rate: 0.4
# learning_rate: 0.001
# Score: 0.727343738079071
#
# Trial 05 summary
# Hyperparameters:
# num_layers: 3
# dense_units: 208
# dropout_rate: 0.4
# learning_rate: 0.001
# Score: 0.7232812643051147
#
# Trial 17 summary
# Hyperparameters:
# num_layers: 1
# dense_units: 160
# dropout_rate: 0.4
# learning_rate: 0.001
# Score: 0.7214062213897705
#
# Trial 01 summary
# Hyperparameters:
# num_layers: 3
# dense_units: 160
# dropout_rate: 0.6
# learning_rate: 0.0001
# Score: 0.7204687595367432
#
# Trial 09 summary
# Hyperparameters:
# num_layers: 1
# dense_units: 64
# dropout_rate: 0.2
# learning_rate: 0.001
# Score: 0.7193750143051147
#
# Trial 14 summary
# Hyperparameters:
# num_layers: 2
# dense_units: 176
# dropout_rate: 0.1
# learning_rate: 0.0001
# Score: 0.7135937213897705
#
# Trial 04 summary
# Hyperparameters:
# num_layers: 3
# dense_units: 224
# dropout_rate: 0.1
# learning_rate: 0.0001
# Score: 0.7126562595367432
# INFO:absl:Tuner results are written to outputs\faizahmp-pipeline\Tuner\tuner_results\69\tuner_results.json.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 69 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'best_hyperparameters': [Artifact(artifact: uri: "outputs\\faizahmp-pipeline\\Tuner\\best_hyperparameters\\69"
# , artifact_type: name: "HyperParameters"
# )], 'tuner_results': [Artifact(artifact: uri: "outputs\\faizahmp-pipeline\\Tuner\\tuner_results\\69"
# , artifact_type: name: "TunerResults"
# )]}) for execution 69
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Tuner is finished.
# INFO:absl:node Trainer is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.trainer.component.Trainer"
#     base_type: TRAIN
#   }
#   id: "Trainer"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "faizahmp-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240728-200402.719488"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "faizahmp-pipeline.Trainer"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240728-200402.719488"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "transformed_examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "hyperparameters"
#     value {
#       channels {
#         producer_node_query {
#           id: "Tuner"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240728-200402.719488"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline.Tuner"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "HyperParameters"
#           }
#         }
#         output_key: "best_hyperparameters"
#       }
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240728-200402.719488"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#     }
#   }
#   inputs {
#     key: "transform_graph"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240728-200402.719488"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "TransformGraph"
#           }
#         }
#         output_key: "transform_graph"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "model"
#     value {
#       artifact_spec {
#         type {
#           name: "Model"
#           base_type: MODEL
#         }
#       }
#     }
#   }
#   outputs {
#     key: "model_run"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelRun"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "eval_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 100,\n  \"splits\": [\n    \"eval\"\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "cardiovaskular_trainer@outputs\\faizahmp-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+16b810556566fc46d1aa85e9566fd8fd64825e6263ba33ed40f38fb7f86902c6-py3-none-any.whl"
#       }
#     }
#   }
#   parameters {
#     key: "train_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 500,\n  \"splits\": [\n    \"train\"\n  ]\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "SchemaGen"
# upstream_nodes: "Transform"
# upstream_nodes: "Tuner"
# downstream_nodes: "Evaluator"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Trainer] Resolved inputs: ({'examples': [Artifact(artifact: id: 51
# type_id: 16
# uri: "outputs\\faizahmp-pipeline\\Transform\\transformed_examples\\67"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1722168338824
# last_update_time_since_epoch: 1722168338824
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'hyperparameters': [Artifact(artifact: id: 53
# type_id: 27
# uri: "outputs\\faizahmp-pipeline\\Tuner\\best_hyperparameters\\69"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1722168505241
# last_update_time_since_epoch: 1722168505241
# , artifact_type: id: 27
# name: "HyperParameters"
# )], 'transform_graph': [Artifact(artifact: id: 46
# type_id: 25
# uri: "outputs\\faizahmp-pipeline\\Transform\\transform_graph\\67"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1722168338820
# last_update_time_since_epoch: 1722168338820
# , artifact_type: id: 25
# name: "TransformGraph"
# )], 'schema': [Artifact(artifact: id: 3
# type_id: 20
# uri: "outputs\\faizahmp-pipeline\\SchemaGen\\schema\\6"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1722133619066
# last_update_time_since_epoch: 1722133619066
# , artifact_type: id: 20
# name: "Schema"
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 70
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=70, input_dict={'examples': [Artifact(artifact: id: 51
# type_id: 16
# uri: "outputs\\faizahmp-pipeline\\Transform\\transformed_examples\\67"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1722168338824
# last_update_time_since_epoch: 1722168338824
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'hyperparameters': [Artifact(artifact: id: 53
# type_id: 27
# uri: "outputs\\faizahmp-pipeline\\Tuner\\best_hyperparameters\\69"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1722168505241
# last_update_time_since_epoch: 1722168505241
# , artifact_type: id: 27
# name: "HyperParameters"
# )], 'transform_graph': [Artifact(artifact: id: 46
# type_id: 25
# uri: "outputs\\faizahmp-pipeline\\Transform\\transform_graph\\67"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1722168338820
# last_update_time_since_epoch: 1722168338820
# , artifact_type: id: 25
# name: "TransformGraph"
# )], 'schema': [Artifact(artifact: id: 3
# type_id: 20
# uri: "outputs\\faizahmp-pipeline\\SchemaGen\\schema\\6"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1722133619066
# last_update_time_since_epoch: 1722133619066
# , artifact_type: id: 20
# name: "Schema"
# )]}, output_dict=defaultdict(<class 'list'>, {'model': [Artifact(artifact: uri: "outputs\\faizahmp-pipeline\\Trainer\\model\\70"
# , artifact_type: name: "Model"
# base_type: MODEL
# )], 'model_run': [Artifact(artifact: uri: "outputs\\faizahmp-pipeline\\Trainer\\model_run\\70"
# , artifact_type: name: "ModelRun"
# )]}), exec_properties={'custom_config': 'null', 'train_args': '{\n  "num_steps": 500,\n  "splits": [\n    "train"\n  ]\n}', 'module_path': 'cardiovaskular_trainer@outputs\\faizahmp-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+16b810556566fc46d1aa85e9566fd8fd64825e6263ba33ed40f38fb7f86902c6-py3-none-any.whl', 'eval_args': '{\n  "num_steps": 100,\n  "splits": [\n    "eval"\n  ]\n}'}, execution_output_uri='outputs\\faizahmp-pipeline\\Trainer\\.system\\executor_execution\\70\\executor_output.pb', stateful_working_dir='outputs\\faizahmp-pipeline\\Trainer\\.system\\stateful_working_dir\\20240728-200402.719488', tmp_dir='outputs\\faizahmp-pipeline\\Trainer\\.system\\executor_execution\\70\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.trainer.component.Trainer"
#     base_type: TRAIN
#   }
#   id: "Trainer"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "faizahmp-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240728-200402.719488"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "faizahmp-pipeline.Trainer"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240728-200402.719488"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "transformed_examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "hyperparameters"
#     value {
#       channels {
#         producer_node_query {
#           id: "Tuner"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240728-200402.719488"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline.Tuner"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "HyperParameters"
#           }
#         }
#         output_key: "best_hyperparameters"
#       }
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240728-200402.719488"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#     }
#   }
#   inputs {
#     key: "transform_graph"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240728-200402.719488"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "TransformGraph"
#           }
#         }
#         output_key: "transform_graph"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "model"
#     value {
#       artifact_spec {
#         type {
#           name: "Model"
#           base_type: MODEL
#         }
#       }
#     }
#   }
#   outputs {
#     key: "model_run"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelRun"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "eval_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 100,\n  \"splits\": [\n    \"eval\"\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "cardiovaskular_trainer@outputs\\faizahmp-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+16b810556566fc46d1aa85e9566fd8fd64825e6263ba33ed40f38fb7f86902c6-py3-none-any.whl"
#       }
#     }
#   }
#   parameters {
#     key: "train_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 500,\n  \"splits\": [\n    \"train\"\n  ]\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "SchemaGen"
# upstream_nodes: "Transform"
# upstream_nodes: "Tuner"
# downstream_nodes: "Evaluator"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "faizahmp-pipeline"
# , pipeline_run_id='20240728-200402.719488')
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# INFO:absl:udf_utils.get_fn {'custom_config': 'null', 'train_args': '{\n  "num_steps": 500,\n  "splits": [\n    "train"\n  ]\n}', 'module_path': 'cardiovaskular_trainer@outputs\\faizahmp-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+16b810556566fc46d1aa85e9566fd8fd64825e6263ba33ed40f38fb7f86902c6-py3-none-any.whl', 'eval_args': '{\n  "num_steps": 100,\n  "splits": [\n    "eval"\n  ]\n}'} 'run_fn'
# INFO:absl:Installing 'outputs\\faizahmp-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+16b810556566fc46d1aa85e9566fd8fd64825e6263ba33ed40f38fb7f86902c6-py3-none-any.whl' to a temporary directory.
# INFO:absl:Executing: ['c:\\Users\\ASUS\\anaconda3\\envs\\tfx-sub3\\python.exe', '-m', 'pip', 'install', '--target', 'C:\\Users\\ASUS\\AppData\\Local\\Temp\\tmpz7l4uwca', 'outputs\\faizahmp-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+16b810556566fc46d1aa85e9566fd8fd64825e6263ba33ed40f38fb7f86902c6-py3-none-any.whl']
# INFO:absl:Successfully installed 'outputs\\faizahmp-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+16b810556566fc46d1aa85e9566fd8fd64825e6263ba33ed40f38fb7f86902c6-py3-none-any.whl'.
# INFO:absl:Training model.
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  bp_category_xf (InputLayer)    [(None, 5)]          0           []
#
#  bp_category_encoded_xf (InputL  [(None, 5)]         0           []
#  ayer)
#
#  gender_xf (InputLayer)         [(None, 1)]          0           []
#
#  height_xf (InputLayer)         [(None, 1)]          0           []
#
#  weight_xf (InputLayer)         [(None, 1)]          0           []
#
#  ap_hi_xf (InputLayer)          [(None, 1)]          0           []
#
#  ap_lo_xf (InputLayer)          [(None, 1)]          0           []
#
#  age_years_xf (InputLayer)      [(None, 1)]          0           []
#
#  bmi_xf (InputLayer)            [(None, 1)]          0           []
#
#  cholesterol_xf (InputLayer)    [(None, 1)]          0           []
#
#  gluc_xf (InputLayer)           [(None, 1)]          0           []
#
#  smoke_xf (InputLayer)          [(None, 1)]          0           []
#
#  alco_xf (InputLayer)           [(None, 1)]          0           []
#
#  active_xf (InputLayer)         [(None, 1)]          0           []
#
#  concatenate_1 (Concatenate)    (None, 22)           0           ['bp_category_xf[0][0]',
#                                                                   'bp_category_encoded_xf[0][0]',
#                                                                   'gender_xf[0][0]',
#                                                                   'height_xf[0][0]',
#                                                                   'weight_xf[0][0]',
#                                                                   'ap_hi_xf[0][0]',
#                                                                   'ap_lo_xf[0][0]',
#                                                                   'age_years_xf[0][0]',
#                                                                   'bmi_xf[0][0]',
#                                                                   'cholesterol_xf[0][0]',
#                                                                   'gluc_xf[0][0]',
#                                                                   'smoke_xf[0][0]',
#                                                                   'alco_xf[0][0]',
#                                                                   'active_xf[0][0]']
#
#  dense_4 (Dense)                (None, 80)           1840        ['concatenate_1[0][0]']
#
#  dense_5 (Dense)                (None, 80)           6480        ['dense_4[0][0]']
#
#  dense_6 (Dense)                (None, 80)           6480        ['dense_5[0][0]']
#
#  dense_7 (Dense)                (None, 1)            81          ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 14,881
# Trainable params: 14,881
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/10
# 500/500 [==============================] - 6s 11ms/step - loss: 0.5745 - binary_accuracy: 0.7060 - val_loss: 0.5582 - val_binary_accuracy: 0.7270
# Epoch 2/10
# 500/500 [==============================] - 6s 11ms/step - loss: 0.5548 - binary_accuracy: 0.7245 - val_loss: 0.5494 - val_binary_accuracy: 0.7367
# Epoch 3/10
# 500/500 [==============================] - 6s 11ms/step - loss: 0.5538 - binary_accuracy: 0.7253 - val_loss: 0.5524 - val_binary_accuracy: 0.7280
# Epoch 4/10
# 500/500 [==============================] - 6s 11ms/step - loss: 0.5490 - binary_accuracy: 0.7271 - val_loss: 0.5527 - val_binary_accuracy: 0.7289
# Epoch 5/10
# 500/500 [==============================] - 6s 11ms/step - loss: 0.5519 - binary_accuracy: 0.7280 - val_loss: 0.5499 - val_binary_accuracy: 0.7319
# Epoch 6/10
# 500/500 [==============================] - 5s 11ms/step - loss: 0.5478 - binary_accuracy: 0.7280 - val_loss: 0.5421 - val_binary_accuracy: 0.7259
# Epoch 7/10
# 500/500 [==============================] - 6s 11ms/step - loss: 0.5497 - binary_accuracy: 0.7266 - val_loss: 0.5409 - val_binary_accuracy: 0.7395
# Epoch 8/10
# 500/500 [==============================] - 5s 11ms/step - loss: 0.5477 - binary_accuracy: 0.7291 - val_loss: 0.5351 - val_binary_accuracy: 0.7397
# Epoch 9/10
# 500/500 [==============================] - 6s 11ms/step - loss: 0.5467 - binary_accuracy: 0.7308 - val_loss: 0.5357 - val_binary_accuracy: 0.7427
# Epoch 10/10
# 500/500 [==============================] - 6s 11ms/step - loss: 0.5465 - binary_accuracy: 0.7295 - val_loss: 0.5442 - val_binary_accuracy: 0.7319
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:Assets written to: outputs\faizahmp-pipeline\Trainer\model\70\Format-Serving\assets
# INFO:tensorflow:Assets written to: outputs\faizahmp-pipeline\Trainer\model\70\Format-Serving\assets
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
# INFO:absl:Training complete. Model written to outputs\faizahmp-pipeline\Trainer\model\70\Format-Serving. ModelRun written to outputs\faizahmp-pipeline\Trainer\model_run\70
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 70 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'model': [Artifact(artifact: uri: "outputs\\faizahmp-pipeline\\Trainer\\model\\70"
# , artifact_type: name: "Model"
# base_type: MODEL
# )], 'model_run': [Artifact(artifact: uri: "outputs\\faizahmp-pipeline\\Trainer\\model_run\\70"
# , artifact_type: name: "ModelRun"
# )]}) for execution 70
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Trainer is finished.
# INFO:absl:node Evaluator is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.evaluator.component.Evaluator"
#     base_type: EVALUATE
#   }
#   id: "Evaluator"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "faizahmp-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240728-200402.719488"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "faizahmp-pipeline.Evaluator"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "baseline_model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Latest_blessed_model_resolver"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240728-200402.719488"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline.Latest_blessed_model_resolver"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "CsvExampleGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240728-200402.719488"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline.CsvExampleGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240728-200402.719488"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "blessing"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelBlessing"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "evaluation"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelEvaluation"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "eval_config"
#     value {
#       field_value {
#         string_value: "{\n  \"metrics_specs\": [\n    {\n      \"metrics\": [\n        {\n          \"class_name\": \"AUC\"\n        },\n        {\n          \"class_name\": \"Precision\"\n        },\n        {\n          \"class_name\": \"Recall\"\n        },\n        {\n          \"class_name\": \"ExampleCount\"\n        },\n        {\n          \"class_name\": \"TruePositives\"\n        },\n        {\n          \"class_name\": \"FalsePositives\"\n        },\n        {\n          \"class_name\": \"TrueNegatives\"\n        },\n        {\n          \"class_name\": \"FalseNegatives\"\n        },\n        {\n          \"class_name\": \"BinaryAccuracy\",\n          \"threshold\": {\n            \"change_threshold\": {\n              \"absolute\": 0.0001,\n              \"direction\": \"HIGHER_IS_BETTER\"\n            },\n            \"value_threshold\": {\n              \"lower_bound\": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  \"model_specs\": [\n    {\n      \"label_key\": \"cardio\"\n    }\n  ],\n  \"slicing_specs\": [\n    {},\n    {\n      \"feature_keys\": [\n        \"gender\",\n        \"cholesterol\"\n      ]\n    }\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "example_splits"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "fairness_indicator_thresholds"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
# }
# upstream_nodes: "CsvExampleGen"
# upstream_nodes: "Latest_blessed_model_resolver"
# upstream_nodes: "Trainer"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Evaluator] Resolved inputs: ({'examples': [Artifact(artifact: id: 1
# type_id: 16
# uri: "outputs\\faizahmp-pipeline\\CsvExampleGen\\examples\\3"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "file_format"
#   value {
#     string_value: "tfrecords_gzip"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:6080978,xor_checksum:1721884998,sum_checksum:1721884998"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "payload_format"
#   value {
#     string_value: "FORMAT_TF_EXAMPLE"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1722133563961
# last_update_time_since_epoch: 1722133563961
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'model': [Artifact(artifact: id: 55
# type_id: 30
# uri: "outputs\\faizahmp-pipeline\\Trainer\\model\\70"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1722168572972
# last_update_time_since_epoch: 1722168572972
# , artifact_type: id: 30
# name: "Model"
# base_type: MODEL
# )], 'baseline_model': []},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 71
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=71, input_dict={'examples': [Artifact(artifact: id: 1
# type_id: 16
# uri: "outputs\\faizahmp-pipeline\\CsvExampleGen\\examples\\3"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "file_format"
#   value {
#     string_value: "tfrecords_gzip"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:6080978,xor_checksum:1721884998,sum_checksum:1721884998"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "payload_format"
#   value {
#     string_value: "FORMAT_TF_EXAMPLE"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1722133563961
# last_update_time_since_epoch: 1722133563961
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'model': [Artifact(artifact: id: 55
# type_id: 30
# uri: "outputs\\faizahmp-pipeline\\Trainer\\model\\70"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1722168572972
# last_update_time_since_epoch: 1722168572972
# , artifact_type: id: 30
# name: "Model"
# base_type: MODEL
# )], 'baseline_model': []}, output_dict=defaultdict(<class 'list'>, {'blessing': [Artifact(artifact: uri: "outputs\\faizahmp-pipeline\\Evaluator\\blessing\\71"
# , artifact_type: name: "ModelBlessing"
# )], 'evaluation': [Artifact(artifact: uri: "outputs\\faizahmp-pipeline\\Evaluator\\evaluation\\71"
# , artifact_type: name: "ModelEvaluation"
# )]}), exec_properties={'fairness_indicator_thresholds': 'null', 'eval_config': '{\n  "metrics_specs": [\n    {\n      "metrics": [\n        {\n          "class_name": "AUC"\n        },\n        {\n          "class_name": "Precision"\n        },\n        {\n          "class_name": "Recall"\n        },\n        {\n          "class_name": "ExampleCount"\n        },\n        {\n          "class_name": "TruePositives"\n        },\n        {\n          "class_name": "FalsePositives"\n        },\n        {\n          "class_name": "TrueNegatives"\n        },\n        {\n          "class_name": "FalseNegatives"\n        },\n        {\n          "class_name": "BinaryAccuracy",\n          "threshold": {\n            "change_threshold": {\n              "absolute": 0.0001,\n              "direction": "HIGHER_IS_BETTER"\n            },\n            "value_threshold": {\n              "lower_bound": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  "model_specs": [\n    {\n      "label_key": "cardio"\n    }\n  ],\n  "slicing_specs": [\n    {},\n    {\n      "feature_keys": [\n        "gender",\n        "cholesterol"\n      ]\n    }\n  ]\n}', 'example_splits': 'null'}, execution_output_uri='outputs\\faizahmp-pipeline\\Evaluator\\.system\\executor_execution\\71\\executor_output.pb', stateful_working_dir='outputs\\faizahmp-pipeline\\Evaluator\\.system\\stateful_working_dir\\20240728-200402.719488', tmp_dir='outputs\\faizahmp-pipeline\\Evaluator\\.system\\executor_execution\\71\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.evaluator.component.Evaluator"
#     base_type: EVALUATE
#   }
#   id: "Evaluator"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "faizahmp-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240728-200402.719488"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "faizahmp-pipeline.Evaluator"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "baseline_model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Latest_blessed_model_resolver"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240728-200402.719488"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline.Latest_blessed_model_resolver"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "CsvExampleGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240728-200402.719488"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline.CsvExampleGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240728-200402.719488"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "blessing"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelBlessing"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "evaluation"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelEvaluation"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "eval_config"
#     value {
#       field_value {
#         string_value: "{\n  \"metrics_specs\": [\n    {\n      \"metrics\": [\n        {\n          \"class_name\": \"AUC\"\n        },\n        {\n          \"class_name\": \"Precision\"\n        },\n        {\n          \"class_name\": \"Recall\"\n        },\n        {\n          \"class_name\": \"ExampleCount\"\n        },\n        {\n          \"class_name\": \"TruePositives\"\n        },\n        {\n          \"class_name\": \"FalsePositives\"\n        },\n        {\n          \"class_name\": \"TrueNegatives\"\n        },\n        {\n          \"class_name\": \"FalseNegatives\"\n        },\n        {\n          \"class_name\": \"BinaryAccuracy\",\n          \"threshold\": {\n            \"change_threshold\": {\n              \"absolute\": 0.0001,\n              \"direction\": \"HIGHER_IS_BETTER\"\n            },\n            \"value_threshold\": {\n              \"lower_bound\": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  \"model_specs\": [\n    {\n      \"label_key\": \"cardio\"\n    }\n  ],\n  \"slicing_specs\": [\n    {},\n    {\n      \"feature_keys\": [\n        \"gender\",\n        \"cholesterol\"\n      ]\n    }\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "example_splits"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "fairness_indicator_thresholds"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
# }
# upstream_nodes: "CsvExampleGen"
# upstream_nodes: "Latest_blessed_model_resolver"
# upstream_nodes: "Trainer"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "faizahmp-pipeline"
# , pipeline_run_id='20240728-200402.719488')
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['----direct_num_workers=0']
# INFO:absl:Attempting to infer TFX Python dependency for beam
# ...
# WARNING:apache_beam.runners.portability.local_job_service:Worker: severity: WARN timestamp {   seconds: 1722168637   nanos: 651699781 } message: "Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000001AFCA5F54C0> and <keras.engine.input_layer.InputLayer object at 0x000001B02496C220>)." instruction_id: "bundle_408" log_location: "c:\\Users\\ASUS\\anaconda3\\envs\\tfx-sub3\\lib\\site-packages\\tensorflow\\python\\checkpoint\\restore.py:84" thread: "Thread-13"
# WARNING:apache_beam.runners.portability.local_job_service:Worker: severity: WARN timestamp {   seconds: 1722168639   nanos: 247717857 } message: "Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000001AFEC7B96A0> and <keras.engine.input_layer.InputLayer object at 0x000001AFEC224790>)." instruction_id: "bundle_411" log_location: "c:\\Users\\ASUS\\anaconda3\\envs\\tfx-sub3\\lib\\site-packages\\tensorflow\\python\\checkpoint\\restore.py:84" thread: "Thread-13"
# WARNING:apache_beam.runners.portability.local_job_service:Worker: severity: WARN timestamp {   seconds: 1722168640   nanos: 833788871 } message: "Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000001B0282CC4C0> and <keras.engine.input_layer.InputLayer object at 0x000001AFF6EE2F10>)." instruction_id: "bundle_414" log_location: "c:\\Users\\ASUS\\anaconda3\\envs\\tfx-sub3\\lib\\site-packages\\tensorflow\\python\\checkpoint\\restore.py:84" thread: "Thread-13"
# WARNING:apache_beam.runners.portability.local_job_service:Worker: severity: WARN timestamp {   seconds: 1722168641   nanos: 711741685 } message: "Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000001B02CCBA9A0> and <keras.engine.input_layer.InputLayer object at 0x000001B02CC78910>)." instruction_id: "bundle_414" log_location: "c:\\Users\\ASUS\\anaconda3\\envs\\tfx-sub3\\lib\\site-packages\\tensorflow\\python\\checkpoint\\restore.py:84" thread: "Thread-13"
# INFO:absl:Evaluation complete. Results written to outputs\faizahmp-pipeline\Evaluator\evaluation\71.
# INFO:absl:Checking validation results.
# WARNING:tensorflow:From c:\Users\ASUS\anaconda3\envs\tfx-sub3\lib\site-packages\tensorflow_model_analysis\writers\metrics_plots_and_validations_writer.py:110: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From c:\Users\ASUS\anaconda3\envs\tfx-sub3\lib\site-packages\tensorflow_model_analysis\writers\metrics_plots_and_validations_writer.py:110: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# INFO:absl:Blessing result True written to outputs\faizahmp-pipeline\Evaluator\blessing\71.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 71 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'blessing': [Artifact(artifact: uri: "outputs\\faizahmp-pipeline\\Evaluator\\blessing\\71"
# , artifact_type: name: "ModelBlessing"
# )], 'evaluation': [Artifact(artifact: uri: "outputs\\faizahmp-pipeline\\Evaluator\\evaluation\\71"
# , artifact_type: name: "ModelEvaluation"
# )]}) for execution 71
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Evaluator is finished.
# INFO:absl:node Pusher is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.pusher.component.Pusher"
#     base_type: DEPLOY
#   }
#   id: "Pusher"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "faizahmp-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240728-200402.719488"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "faizahmp-pipeline.Pusher"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240728-200402.719488"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "model_blessing"
#     value {
#       channels {
#         producer_node_query {
#           id: "Evaluator"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240728-200402.719488"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline.Evaluator"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ModelBlessing"
#           }
#         }
#         output_key: "blessing"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "pushed_model"
#     value {
#       artifact_spec {
#         type {
#           name: "PushedModel"
#           base_type: MODEL
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "push_destination"
#     value {
#       field_value {
#         string_value: "{\n  \"filesystem\": {\n    \"base_directory\": \"outputs\\\\serving_model\"\n  }\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "Evaluator"
# upstream_nodes: "Trainer"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Pusher] Resolved inputs: ({'model': [Artifact(artifact: id: 55
# type_id: 30
# uri: "outputs\\faizahmp-pipeline\\Trainer\\model\\70"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1722168572972
# last_update_time_since_epoch: 1722168572972
# , artifact_type: id: 30
# name: "Model"
# base_type: MODEL
# )], 'model_blessing': [Artifact(artifact: id: 57
# type_id: 33
# uri: "outputs\\faizahmp-pipeline\\Evaluator\\blessing\\71"
# custom_properties {
#   key: "blessed"
#   value {
#     int_value: 1
#   }
# }
# custom_properties {
#   key: "current_model"
#   value {
#     string_value: "outputs\\faizahmp-pipeline\\Trainer\\model\\70"
#   }
# }
# custom_properties {
#   key: "current_model_id"
#   value {
#     int_value: 55
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1722168645131
# last_update_time_since_epoch: 1722168645131
# , artifact_type: id: 33
# name: "ModelBlessing"
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 72
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=72, input_dict={'model': [Artifact(artifact: id: 55
# type_id: 30
# uri: "outputs\\faizahmp-pipeline\\Trainer\\model\\70"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1722168572972
# last_update_time_since_epoch: 1722168572972
# , artifact_type: id: 30
# name: "Model"
# base_type: MODEL
# )], 'model_blessing': [Artifact(artifact: id: 57
# type_id: 33
# uri: "outputs\\faizahmp-pipeline\\Evaluator\\blessing\\71"
# custom_properties {
#   key: "blessed"
#   value {
#     int_value: 1
#   }
# }
# custom_properties {
#   key: "current_model"
#   value {
#     string_value: "outputs\\faizahmp-pipeline\\Trainer\\model\\70"
#   }
# }
# custom_properties {
#   key: "current_model_id"
#   value {
#     int_value: 55
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1722168645131
# last_update_time_since_epoch: 1722168645131
# , artifact_type: id: 33
# name: "ModelBlessing"
# )]}, output_dict=defaultdict(<class 'list'>, {'pushed_model': [Artifact(artifact: uri: "outputs\\faizahmp-pipeline\\Pusher\\pushed_model\\72"
# , artifact_type: name: "PushedModel"
# base_type: MODEL
# )]}), exec_properties={'push_destination': '{\n  "filesystem": {\n    "base_directory": "outputs\\\\serving_model"\n  }\n}', 'custom_config': 'null'}, execution_output_uri='outputs\\faizahmp-pipeline\\Pusher\\.system\\executor_execution\\72\\executor_output.pb', stateful_working_dir='outputs\\faizahmp-pipeline\\Pusher\\.system\\stateful_working_dir\\20240728-200402.719488', tmp_dir='outputs\\faizahmp-pipeline\\Pusher\\.system\\executor_execution\\72\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.pusher.component.Pusher"
#     base_type: DEPLOY
#   }
#   id: "Pusher"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "faizahmp-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240728-200402.719488"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "faizahmp-pipeline.Pusher"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240728-200402.719488"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "model_blessing"
#     value {
#       channels {
#         producer_node_query {
#           id: "Evaluator"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240728-200402.719488"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "faizahmp-pipeline.Evaluator"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ModelBlessing"
#           }
#         }
#         output_key: "blessing"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "pushed_model"
#     value {
#       artifact_spec {
#         type {
#           name: "PushedModel"
#           base_type: MODEL
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "push_destination"
#     value {
#       field_value {
#         string_value: "{\n  \"filesystem\": {\n    \"base_directory\": \"outputs\\\\serving_model\"\n  }\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "Evaluator"
# upstream_nodes: "Trainer"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "faizahmp-pipeline"
# , pipeline_run_id='20240728-200402.719488')
# INFO:absl:Model version: 1722168646
# INFO:absl:Model written to serving path outputs\serving_model\1722168646.
# INFO:absl:Model pushed to outputs\faizahmp-pipeline\Pusher\pushed_model\72.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 72 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'pushed_model': [Artifact(artifact: uri: "outputs\\faizahmp-pipeline\\Pusher\\pushed_model\\72"
# , artifact_type: name: "PushedModel"
# base_type: MODEL
# )]}) for execution 72
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Pusher is finished.
